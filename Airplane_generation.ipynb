# %%
import scipy
from tensorflow.python.keras.layers import Input, Dense, Reshape, Flatten, Dropout, Concatenate, LeakyReLU
from tensorflow.python.keras.layers import BatchNormalization, Add, add
from tensorflow.python.keras.layers import UpSampling2D, Conv2D
from tensorflow.python.keras.applications import vgg19
from keras.utils import plot_model
from keras.preprocessing.image import img_to_array, load_img
from keras.models import Sequential, Model
from keras.optimizers import Adam
import matplotlib.pyplot as plt
import numpy as np
import os
import tensorflow.python.keras.backend as K
from tqdm import tqdm

from tensorflow.python.platform.tf_logging import set_verbosity, FATAL
set_verbosity(FATAL)
os.environ["TF_CPP_MIN_LOG_LEVEL"] = '0'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
img_shape = (256,384,3)
height=img_shape[0]
width=img_shape[1]

# %%
# !unzip -q '/content/drive/My Drive/Базы/Airplanes.zip'

# %%
imgs = []
for image in sorted(os.listdir('img')):
  print(image)
  imgs.append(img_to_array(load_img('img/'+image, target_size=(height,width))))
imgs = np.stack(imgs).astype('uint8')

masks = []
for image in sorted(os.listdir('mask')):
  masks.append(img_to_array(load_img('mask/'+image, target_size=(height,width))))
masks = np.stack(masks).astype('uint8')
# Out:
# airplane_1.jpg
# airplane_10.jpg
# airplane_100.jpg
# airplane_1000.jpg
# airplane_101.jpg
# airplane_102.jpg
# airplane_103.jpg
# airplane_104.jpg
# airplane_105.jpg
# airplane_106.jpg
# airplane_107.jpg
# airplane_108.jpg
# airplane_109.jpg
# airplane_11.jpg
# airplane_110.jpg
# airplane_111.jpg
# airplane_112.jpg
# airplane_113.jpg
# airplane_114.jpg
# airplane_115.jpg
# airplane_116.jpg
# airplane_117.jpg
# airplane_118.jpg
# airplane_119.jpg
# airplane_12.jpg
# airplane_120.jpg
# airplane_121.jpg
# airplane_122.jpg
# airplane_123.jpg
# airplane_124.jpg
# airplane_125.jpg
# airplane_126.jpg
# airplane_127.jpg
# airplane_128.jpg
# airplane_129.jpg
# airplane_13.jpg
# airplane_130.jpg
# airplane_131.jpg
# airplane_132.jpg
# airplane_133.jpg
# airplane_134.jpg
# airplane_135.jpg
# airplane_136.jpg
# airplane_137.jpg
# airplane_138.jpg
# airplane_139.jpg
# airplane_14.jpg
# airplane_140.jpg
# airplane_141.jpg
# airplane_142.jpg
# airplane_143.jpg
# airplane_144.jpg
# airplane_145.jpg
# airplane_146.jpg
# airplane_147.jpg
# airplane_148.jpg
# airplane_149.jpg
# airplane_15.jpg
# airplane_150.jpg
# airplane_151.jpg
# airplane_152.jpg
# airplane_153.jpg
# airplane_154.jpg
# airplane_155.jpg
# airplane_156.jpg
# airplane_157.jpg
# airplane_158.jpg
# airplane_159.jpg
# airplane_16.jpg
# airplane_160.jpg
# airplane_161.jpg
# airplane_162.jpg
# airplane_163.jpg
# airplane_164.jpg
# airplane_165.jpg
# airplane_166.jpg
# airplane_167.jpg
# airplane_168.jpg
# airplane_169.jpg
# airplane_17.jpg
# airplane_170.jpg
# airplane_171.jpg
# airplane_172.jpg
# airplane_173.jpg
# airplane_174.jpg
# airplane_175.jpg
# airplane_176.jpg
# airplane_177.jpg
# airplane_178.jpg
# airplane_179.jpg
# airplane_18.jpg
# airplane_180.jpg
# airplane_181.jpg
# airplane_182.jpg
# airplane_183.jpg
# airplane_184.jpg
# airplane_185.jpg
# airplane_186.jpg
# airplane_187.jpg
# airplane_188.jpg
# airplane_189.jpg
# airplane_19.jpg
# airplane_190.jpg
# airplane_191.jpg
# airplane_192.jpg
# airplane_193.jpg
# airplane_194.jpg
# airplane_195.jpg
# airplane_196.jpg
# airplane_197.jpg
# airplane_198.jpg
# airplane_199.jpg
# airplane_2.jpg
# airplane_20.jpg
# airplane_200.jpg
# airplane_201.jpg
# airplane_202.jpg
# airplane_203.jpg
# airplane_204.jpg
# airplane_205.jpg
# airplane_206.jpg
# airplane_207.jpg
# airplane_208.jpg
# airplane_209.jpg
# airplane_21.jpg
# airplane_210.jpg
# airplane_211.jpg
# airplane_212.jpg
# airplane_213.jpg
# airplane_214.jpg
# airplane_215.jpg
# airplane_216.jpg
# airplane_217.jpg
# airplane_218.jpg
# airplane_219.jpg
# airplane_22.jpg
# airplane_220.jpg
# airplane_221.jpg
# airplane_222.jpg
# airplane_223.jpg
# airplane_224.jpg
# airplane_225.jpg
# airplane_226.jpg
# airplane_227.jpg
# airplane_228.jpg
# airplane_229.jpg
# airplane_23.jpg
# airplane_230.jpg
# airplane_231.jpg
# airplane_232.jpg
# airplane_233.jpg
# airplane_234.jpg
# airplane_235.jpg
# airplane_236.jpg
# airplane_237.jpg
# airplane_238.jpg
# airplane_239.jpg
# airplane_24.jpg
# airplane_240.jpg
# airplane_241.jpg
# airplane_242.jpg
# airplane_243.jpg
# airplane_244.jpg
# airplane_245.jpg
# airplane_246.jpg
# airplane_247.jpg
# airplane_248.jpg
# airplane_249.jpg
# airplane_25.jpg
# airplane_250.jpg
# airplane_251.jpg
# airplane_252.jpg
# airplane_253.jpg
# airplane_254.jpg
# airplane_255.jpg
# airplane_256.jpg
# airplane_257.jpg
# airplane_258.jpg
# airplane_259.jpg
# airplane_26.jpg
# airplane_260.jpg
# airplane_261.jpg
# airplane_262.jpg
# airplane_263.jpg
# airplane_264.jpg
# airplane_265.jpg
# airplane_266.jpg
# airplane_267.jpg
# airplane_268.jpg
# airplane_269.jpg
# airplane_27.jpg
# airplane_270.jpg
# airplane_271.jpg
# airplane_272.jpg
# airplane_273.jpg
# airplane_274.jpg
# airplane_275.jpg
# airplane_276.jpg
# airplane_277.jpg
# airplane_278.jpg
# airplane_279.jpg
# airplane_28.jpg
# airplane_280.jpg
# airplane_281.jpg
# airplane_282.jpg
# airplane_283.jpg
# airplane_284.jpg
# airplane_285.jpg
# airplane_286.jpg
# airplane_287.jpg
# airplane_288.jpg
# airplane_289.jpg
# airplane_29.jpg
# airplane_290.jpg
# airplane_291.jpg
# airplane_292.jpg
# airplane_293.jpg
# airplane_294.jpg
# airplane_295.jpg
# airplane_296.jpg
# airplane_297.jpg
# airplane_298.jpg
# airplane_299.jpg
# airplane_3.jpg
# airplane_30.jpg
# airplane_300.jpg
# airplane_301.jpg
# airplane_302.jpg
# airplane_303.jpg
# airplane_304.jpg
# airplane_305.jpg
# airplane_306.jpg
# airplane_307.jpg
# airplane_308.jpg
# airplane_309.jpg
# airplane_31.jpg
# airplane_310.jpg
# airplane_311.jpg
# airplane_312.jpg
# airplane_313.jpg
# airplane_314.jpg
# airplane_315.jpg
# airplane_316.jpg
# airplane_317.jpg
# airplane_318.jpg
# airplane_319.jpg
# airplane_32.jpg
# airplane_320.jpg
# airplane_321.jpg
# airplane_322.jpg
# airplane_323.jpg
# airplane_324.jpg
# airplane_325.jpg
# airplane_326.jpg
# airplane_327.jpg
# airplane_328.jpg
# airplane_329.jpg
# airplane_33.jpg
# airplane_330.jpg
# airplane_331.jpg
# airplane_332.jpg
# airplane_333.jpg
# airplane_334.jpg
# airplane_335.jpg
# airplane_336.jpg
# airplane_337.jpg
# airplane_338.jpg
# airplane_339.jpg
# airplane_34.jpg
# airplane_340.jpg
# airplane_341.jpg
# airplane_342.jpg
# airplane_343.jpg
# airplane_344.jpg
# airplane_345.jpg
# airplane_346.jpg
# airplane_347.jpg
# airplane_348.jpg
# airplane_349.jpg
# airplane_35.jpg
# airplane_350.jpg
# airplane_351.jpg
# airplane_352.jpg
# airplane_353.jpg
# airplane_354.jpg
# airplane_355.jpg
# airplane_356.jpg
# airplane_357.jpg
# airplane_358.jpg
# airplane_359.jpg
# airplane_36.jpg
# airplane_360.jpg
# airplane_361.jpg
# airplane_362.jpg
# airplane_363.jpg
# airplane_364.jpg
# airplane_365.jpg
# airplane_366.jpg
# airplane_367.jpg
# airplane_368.jpg
# airplane_369.jpg
# airplane_37.jpg
# airplane_370.jpg
# airplane_371.jpg
# airplane_372.jpg
# airplane_373.jpg
# airplane_374.jpg
# airplane_375.jpg
# airplane_376.jpg
# airplane_377.jpg
# airplane_378.jpg
# airplane_379.jpg
# airplane_38.jpg
# airplane_380.jpg
# airplane_381.jpg
# airplane_382.jpg
# airplane_383.jpg
# airplane_384.jpg
# airplane_385.jpg
# airplane_386.jpg
# airplane_387.jpg
# airplane_388.jpg
# airplane_389.jpg
# airplane_39.jpg
# airplane_390.jpg
# airplane_391.jpg
# airplane_392.jpg
# airplane_393.jpg
# airplane_394.jpg
# airplane_395.jpg
# airplane_396.jpg
# airplane_397.jpg
# airplane_398.jpg
# airplane_399.jpg
# airplane_4.jpg
# airplane_40.jpg
# airplane_400.jpg
# airplane_401.jpg
# airplane_402.jpg
# airplane_403.jpg
# airplane_404.jpg
# airplane_405.jpg
# airplane_406.jpg
# airplane_407.jpg
# airplane_408.jpg
# airplane_409.jpg
# airplane_41.jpg
# airplane_410.jpg
# airplane_411.jpg
# airplane_412.jpg
# airplane_413.jpg
# airplane_414.jpg
# airplane_415.jpg
# airplane_416.jpg
# airplane_417.jpg
# airplane_418.jpg
# airplane_419.jpg
# airplane_42.jpg
# airplane_420.jpg
# airplane_421.jpg
# airplane_422.jpg
# airplane_423.jpg
# airplane_424.jpg
# airplane_425.jpg
# airplane_426.jpg
# airplane_427.jpg
# airplane_428.jpg
# airplane_429.jpg
# airplane_43.jpg
# airplane_430.jpg
# airplane_431.jpg
# airplane_432.jpg
# airplane_433.jpg
# airplane_434.jpg
# airplane_435.jpg
# airplane_436.jpg
# airplane_437.jpg
# airplane_438.jpg
# airplane_439.jpg
# airplane_44.jpg
# airplane_440.jpg
# airplane_441.jpg
# airplane_442.jpg
# airplane_443.jpg
# airplane_444.jpg
# airplane_445.jpg
# airplane_446.jpg
# airplane_447.jpg
# airplane_448.jpg
# airplane_449.jpg
# airplane_45.jpg
# airplane_450.jpg
# airplane_451.jpg
# airplane_452.jpg
# airplane_453.jpg
# airplane_454.jpg
# airplane_455.jpg
# airplane_456.jpg
# airplane_457.jpg
# airplane_458.jpg
# airplane_459.jpg
# airplane_46.jpg
# airplane_460.jpg
# airplane_461.jpg
# airplane_462.jpg
# airplane_463.jpg
# airplane_464.jpg
# airplane_465.jpg
# airplane_466.jpg
# airplane_467.jpg
# airplane_468.jpg
# airplane_469.jpg
# airplane_47.jpg
# airplane_470.jpg
# airplane_471.jpg
# airplane_472.jpg
# airplane_473.jpg
# airplane_474.jpg
# airplane_475.jpg
# airplane_476.jpg
# airplane_477.jpg
# airplane_478.jpg
# airplane_479.jpg
# airplane_48.jpg
# airplane_480.jpg
# airplane_481.jpg
# airplane_482.jpg
# airplane_483.jpg
# airplane_484.jpg
# airplane_485.jpg
# airplane_486.jpg
# airplane_487.jpg
# airplane_488.jpg
# airplane_489.jpg
# airplane_49.jpg
# airplane_490.jpg
# airplane_491.jpg
# airplane_492.jpg
# airplane_493.jpg
# airplane_494.jpg
# airplane_495.jpg
# airplane_496.jpg
# airplane_497.jpg
# airplane_498.jpg
# airplane_499.jpg
# airplane_5.jpg
# airplane_50.jpg
# airplane_500.jpg
# airplane_501.jpg
# airplane_502.jpg
# airplane_503.jpg
# airplane_504.jpg
# airplane_505.jpg
# airplane_506.jpg
# airplane_507.jpg
# airplane_508.jpg
# airplane_509.jpg
# airplane_51.jpg
# airplane_510.jpg
# airplane_511.jpg
# airplane_512.jpg
# airplane_513.jpg
# airplane_514.jpg
# airplane_515.jpg
# airplane_516.jpg
# airplane_517.jpg
# airplane_518.jpg
# airplane_519.jpg
# airplane_52.jpg
# airplane_520.jpg
# airplane_521.jpg
# airplane_522.jpg
# airplane_523.jpg
# airplane_524.jpg
# airplane_525.jpg
# airplane_526.jpg
# airplane_527.jpg
# airplane_528.jpg
# airplane_529.jpg
# airplane_53.jpg
# airplane_530.jpg
# airplane_531.jpg
# airplane_532.jpg
# airplane_533.jpg
# airplane_534.jpg
# airplane_535.jpg
# airplane_536.jpg
# airplane_537.jpg
# airplane_538.jpg
# airplane_539.jpg
# airplane_54.jpg
# airplane_540.jpg
# airplane_541.jpg
# airplane_542.jpg
# airplane_543.jpg
# airplane_544.jpg
# airplane_545.jpg
# airplane_546.jpg
# airplane_547.jpg
# airplane_548.jpg
# airplane_549.jpg
# airplane_55.jpg
# airplane_550.jpg
# airplane_551.jpg
# airplane_552.jpg
# airplane_553.jpg
# airplane_554.jpg
# airplane_555.jpg
# airplane_556.jpg
# airplane_557.jpg
# airplane_558.jpg
# airplane_559.jpg
# airplane_56.jpg
# airplane_560.jpg
# airplane_561.jpg
# airplane_562.jpg
# airplane_563.jpg
# airplane_564.jpg
# airplane_565.jpg
# airplane_566.jpg
# airplane_567.jpg
# airplane_568.jpg
# airplane_569.jpg
# airplane_57.jpg
# airplane_570.jpg
# airplane_571.jpg
# airplane_572.jpg
# airplane_573.jpg
# airplane_574.jpg
# airplane_575.jpg
# airplane_576.jpg
# airplane_577.jpg
# airplane_578.jpg
# airplane_579.jpg
# airplane_58.jpg
# airplane_580.jpg
# airplane_581.jpg
# airplane_582.jpg
# airplane_583.jpg
# airplane_584.jpg
# airplane_585.jpg
# airplane_586.jpg
# airplane_587.jpg
# airplane_588.jpg
# airplane_589.jpg
# airplane_59.jpg
# airplane_590.jpg
# airplane_591.jpg
# airplane_592.jpg
# airplane_593.jpg
# airplane_594.jpg
# airplane_595.jpg
# airplane_596.jpg
# airplane_597.jpg
# airplane_598.jpg
# airplane_599.jpg
# airplane_6.jpg
# airplane_60.jpg
# airplane_600.jpg
# airplane_601.jpg
# airplane_602.jpg
# airplane_603.jpg
# airplane_604.jpg
# airplane_605.jpg
# airplane_606.jpg
# airplane_607.jpg
# airplane_608.jpg
# airplane_609.jpg
# airplane_61.jpg
# airplane_610.jpg
# airplane_611.jpg
# airplane_612.jpg
# airplane_613.jpg
# airplane_614.jpg
# airplane_615.jpg
# airplane_616.jpg
# airplane_617.jpg
# airplane_618.jpg
# airplane_619.jpg
# airplane_62.jpg
# airplane_620.jpg
# airplane_621.jpg
# airplane_622.jpg
# airplane_623.jpg
# airplane_624.jpg
# airplane_625.jpg
# airplane_626.jpg
# airplane_627.jpg
# airplane_628.jpg
# airplane_629.jpg
# airplane_63.jpg
# airplane_630.jpg
# airplane_631.jpg
# airplane_632.jpg
# airplane_633.jpg
# airplane_634.jpg
# airplane_635.jpg
# airplane_636.jpg
# airplane_637.jpg
# airplane_638.jpg
# airplane_639.jpg
# airplane_64.jpg
# airplane_640.jpg
# airplane_641.jpg
# airplane_642.jpg
# airplane_643.jpg
# airplane_644.jpg
# airplane_645.jpg
# airplane_646.jpg
# airplane_647.jpg
# airplane_648.jpg
# airplane_649.jpg
# airplane_65.jpg
# airplane_650.jpg
# airplane_651.jpg
# airplane_652.jpg
# airplane_653.jpg
# airplane_654.jpg
# airplane_655.jpg
# airplane_656.jpg
# airplane_657.jpg
# airplane_658.jpg
# airplane_659.jpg
# airplane_66.jpg
# airplane_660.jpg
# airplane_661.jpg
# airplane_662.jpg
# airplane_663.jpg
# airplane_664.jpg
# airplane_665.jpg
# airplane_666.jpg
# airplane_667.jpg
# airplane_668.jpg
# airplane_669.jpg
# airplane_67.jpg
# airplane_670.jpg
# airplane_671.jpg
# airplane_672.jpg
# airplane_673.jpg
# airplane_674.jpg
# airplane_675.JPG
# airplane_676.jpg
# airplane_677.jpg
# airplane_678.jpg
# airplane_679.jpg
# airplane_68.jpg
# airplane_680.jpg
# airplane_681.jpg
# airplane_682.jpg
# airplane_683.jpg
# airplane_684.jpg
# airplane_685.jpg
# airplane_686.jpg
# airplane_687.jpg
# airplane_688.jpg
# airplane_689.jpg
# airplane_69.jpg
# airplane_690.jpg
# airplane_691.jpg
# airplane_692.jpg
# airplane_693.jpg
# airplane_694.jpg
# airplane_695.jpg
# airplane_696.jpg
# airplane_697.jpg
# airplane_698.jpg
# airplane_699.jpg
# airplane_7.jpg
# airplane_70.jpg
# airplane_700.jpg
# airplane_701.jpg
# airplane_702.jpg
# airplane_703.jpg
# airplane_704.jpg
# airplane_705.jpg
# airplane_706.jpg
# airplane_707.jpg
# airplane_708.jpg
# airplane_709.jpg
# airplane_71.jpg
# airplane_710.jpg
# airplane_711.jpg
# airplane_712.jpg
# airplane_713.jpg
# airplane_714.jpg
# airplane_715.jpg
# airplane_716.jpg
# airplane_717.jpg
# airplane_718.jpg
# airplane_719.jpg
# airplane_72.jpg
# airplane_720.jpg
# airplane_721.jpg
# airplane_722.jpg
# airplane_723.jpg
# airplane_724.jpg
# airplane_725.jpg
# airplane_726.jpg
# airplane_727.jpg
# airplane_728.jpg
# airplane_729.jpg
# airplane_73.jpg
# airplane_730.jpg
# airplane_731.jpg
# airplane_732.jpg
# airplane_733.jpg
# airplane_734.jpg
# airplane_735.jpg
# airplane_736.jpg
# airplane_737.jpg
# airplane_738.jpg
# airplane_739.jpg
# airplane_74.jpg
# airplane_740.jpg
# airplane_741.jpg
# airplane_742.jpg
# airplane_743.jpg
# airplane_744.jpg
# airplane_745.jpg
# airplane_746.jpg
# airplane_747.jpg
# airplane_748.jpg
# airplane_749.jpg
# airplane_75.jpg
# airplane_750.jpg
# airplane_751.jpg
# airplane_752.jpg
# airplane_753.jpg
# airplane_754.jpg
# airplane_755.jpg
# airplane_756.jpg
# airplane_757.jpg
# airplane_758.jpg
# airplane_759.jpg
# airplane_76.jpg
# airplane_760.jpg
# airplane_761.jpg
# airplane_762.jpg
# airplane_763.jpg
# airplane_764.jpg
# airplane_765.jpg
# airplane_766.jpg
# airplane_767.jpg
# airplane_768.jpg
# airplane_769.jpg
# airplane_77.jpg
# airplane_770.jpg
# airplane_771.jpg
# airplane_772.jpg
# airplane_773.jpg
# airplane_774.jpg
# airplane_775.jpg
# airplane_776.jpg
# airplane_777.jpg
# airplane_778.jpg
# airplane_779.jpg
# airplane_78.jpg
# airplane_780.jpg
# airplane_781.jpg
# airplane_782.jpg
# airplane_783.jpg
# airplane_784.jpg
# airplane_785.jpg
# airplane_786.jpg
# airplane_787.jpg
# airplane_788.jpg
# airplane_789.jpg
# airplane_79.jpg
# airplane_790.jpg
# airplane_791.jpg
# airplane_792.jpg
# airplane_793.jpg
# airplane_794.jpg
# airplane_795.jpg
# airplane_796.jpg
# airplane_797.jpg
# airplane_798.jpg
# airplane_799.jpg
# airplane_8.jpg
# airplane_80.jpg
# airplane_800.jpg
# airplane_801.jpg
# airplane_802.jpg
# airplane_803.jpg
# airplane_804.jpg
# airplane_805.jpg
# airplane_806.jpg
# airplane_807.jpg
# airplane_808.jpg
# airplane_809.jpg
# airplane_81.jpg
# airplane_810.jpg
# airplane_811.jpg
# airplane_812.jpg
# airplane_813.jpg
# airplane_814.jpg
# airplane_815.jpg
# airplane_816.jpg
# airplane_817.jpg
# airplane_818.jpg
# airplane_819.jpg
# airplane_82.jpg
# airplane_820.jpg
# airplane_821.jpg
# airplane_822.jpg
# airplane_823.jpg
# airplane_824.jpg
# airplane_825.jpg
# airplane_826.jpg
# airplane_827.jpg
# airplane_828.jpg
# airplane_829.jpg
# airplane_83.jpg
# airplane_830.jpg
# airplane_831.jpg
# airplane_832.jpg
# airplane_833.jpg
# airplane_834.jpg
# airplane_835.jpg
# airplane_836.jpg
# airplane_837.jpg
# airplane_838.jpg
# airplane_839.jpg
# airplane_84.jpg
# airplane_840.jpg
# airplane_841.jpg
# airplane_842.jpg
# airplane_843.jpg
# airplane_844.jpg
# airplane_845.jpg
# airplane_846.jpg
# airplane_847.jpg
# airplane_848.jpg
# airplane_849.jpg
# airplane_85.jpg
# airplane_850.jpg
# airplane_851.jpg
# airplane_852.jpg
# airplane_853.jpg
# airplane_854.jpg
# airplane_855.jpg
# airplane_856.jpg
# airplane_857.jpg
# airplane_858.jpg
# airplane_859.jpg
# airplane_86.jpg
# airplane_860.jpg
# airplane_861.jpg
# airplane_862.jpg
# airplane_863.jpg
# airplane_864.jpg
# airplane_865.jpg
# airplane_866.jpg
# airplane_867.jpg
# airplane_868.jpg
# airplane_869.jpg
# airplane_87.jpg
# airplane_870.jpg
# airplane_871.jpg
# airplane_872.jpg
# airplane_873.jpg
# airplane_874.jpg
# airplane_875.jpg
# airplane_876.jpg
# airplane_877.jpg
# airplane_878.jpg
# airplane_879.jpg
# airplane_88.jpg
# airplane_880.jpg
# airplane_881.jpg
# airplane_882.jpg
# airplane_883.jpg
# airplane_884.jpg
# airplane_885.jpg
# airplane_886.jpg
# airplane_887.jpg
# airplane_888.jpg
# airplane_889.jpg
# airplane_89.jpg
# airplane_890.jpg
# airplane_891.jpg
# airplane_892.jpg
# airplane_893.jpg
# airplane_894.jpg
# airplane_895.jpg
# airplane_896.jpg
# airplane_897.jpg
# airplane_898.jpg
# airplane_899.jpg
# airplane_9.jpg
# airplane_90.jpg
# airplane_900.jpg
# airplane_901.jpg
# airplane_902.jpg
# airplane_903.jpg
# airplane_904.jpg
# airplane_905.jpg
# airplane_906.jpg
# airplane_907.jpg
# airplane_908.jpg
# airplane_909.jpg
# airplane_91.jpg
# airplane_910.jpg
# airplane_911.jpg
# airplane_912.jpg
# airplane_913.jpg
# airplane_914.jpg
# airplane_915.jpg
# airplane_916.jpg
# airplane_917.jpg
# airplane_918.jpg
# airplane_919.jpg
# airplane_92.jpg
# airplane_920.jpg
# airplane_921.jpg
# airplane_922.jpg
# airplane_923.jpg
# airplane_924.jpg
# airplane_925.jpg
# airplane_926.JPG
# airplane_927.jpg
# airplane_928.jpg
# airplane_929.jpg
# airplane_93.jpg
# airplane_930.jpg
# airplane_931.jpg
# airplane_932.jpg
# airplane_933.jpg
# airplane_934.jpg
# airplane_935.jpg
# airplane_936.jpg
# airplane_937.jpg
# airplane_938.jpg
# airplane_939.jpg
# airplane_94.jpg
# airplane_940.jpg
# airplane_941.jpg
# airplane_942.jpg
# airplane_943.jpg
# airplane_944.jpg
# airplane_945.jpg
# airplane_946.jpg
# airplane_947.jpg
# airplane_948.jpg
# airplane_949.jpg
# airplane_95.jpg
# airplane_950.jpg
# airplane_951.jpg
# airplane_952.jpg
# airplane_953.jpg
# airplane_954.jpg
# airplane_955.jpg
# airplane_956.jpg
# airplane_957.jpg
# airplane_958.jpg
# airplane_959.jpg
# airplane_96.jpg
# airplane_960.jpg
# airplane_961.jpg
# airplane_962.jpg
# airplane_963.jpg
# airplane_964.jpg
# airplane_965.jpg
# airplane_966.jpg
# airplane_967.jpg
# airplane_968.jpg
# airplane_969.jpg
# airplane_97.jpg
# airplane_970.jpg
# airplane_971.jpg
# airplane_972.jpg
# airplane_973.jpg
# airplane_974.jpg
# airplane_975.jpg
# airplane_976.jpg
# airplane_977.jpg
# airplane_978.jpg
# airplane_979.jpg
# airplane_98.jpg
# airplane_980.jpg
# airplane_981.jpg
# airplane_982.jpg
# airplane_983.jpg
# airplane_984.jpg
# airplane_985.jpg
# airplane_986.jpg
# airplane_987.jpg
# airplane_988.jpg
# airplane_989.jpg
# airplane_99.jpg
# airplane_990.jpg
# airplane_991.jpg
# airplane_992.jpg
# airplane_993.jpg
# airplane_994.jpg
# airplane_995.jpg
# airplane_996.jpg
# airplane_997.jpg
# airplane_998.jpg
# airplane_999.jpg

# %%
def build_generator():
    gf = 64

    def conv2d(layer_input, filters, f_size=4, bn=True):

        d = Conv2D(filters, kernel_size=f_size, strides=2, padding='same')(layer_input)
        d = LeakyReLU(alpha=0.2)(d)
        if bn:
            d = BatchNormalization(momentum=0.8)(d)
        return d

    def deconv2d(layer_input, skip_input, filters, f_size=4, dropout_rate=0):
        u = UpSampling2D(size=2)(layer_input)
        u = Conv2D(filters, kernel_size=f_size, strides=1, padding='same', activation='relu')(u)
        if dropout_rate:
            u = Dropout(dropout_rate)(u)
        u = BatchNormalization(momentum=0.8)(u)
        u = Concatenate()([u, skip_input])
        return u


    d0 = Input(shape=img_shape, name="condition")

    d1 = conv2d(d0, gf, bn=False)
    d2 = conv2d(d1, gf*2)
    d3 = conv2d(d2, gf*4)
    d4 = conv2d(d3, gf*8)
    d5 = conv2d(d4, gf*8)
    d6 = conv2d(d5, gf*8)
    d7 = conv2d(d6, gf*8)

    u1 = deconv2d(d7, d6, gf*8)
    u2 = deconv2d(u1, d5, gf*8)
    u3 = deconv2d(u2, d4, gf*8)
    u4 = deconv2d(u3, d3, gf*4)
    u5 = deconv2d(u4, d2, gf*2)
    u6 = deconv2d(u5, d1, gf)

    u7 = UpSampling2D(size=2)(u6)
    output_img = Conv2D(3, kernel_size=4, strides=1, padding='same', activation='tanh', name='G_output')(u7)

    return Model(d0, output_img, name="G")

# %%
gen = build_generator()
gen.summary()
# Out:
# Model: "G"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# condition (InputLayer)          [(None, 256, 384, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 128, 192, 64) 3136        condition[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 128, 192, 64) 0           conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 64, 96, 128)  131200      leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 64, 96, 128)  0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 64, 96, 128)  512         leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 48, 256)  524544      batch_normalization[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 32, 48, 256)  0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 32, 48, 256)  1024        leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 16, 24, 512)  2097664     batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 16, 24, 512)  0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 16, 24, 512)  2048        leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 8, 12, 512)   4194816     batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 8, 12, 512)   0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 8, 12, 512)   2048        leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 4, 6, 512)    4194816     batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 4, 6, 512)    0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 4, 6, 512)    2048        leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 2, 3, 512)    4194816     batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 2, 3, 512)    0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 2, 3, 512)    2048        leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 4, 6, 512)    0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 4, 6, 512)    4194816     up_sampling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 4, 6, 512)    2048        conv2d_7[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 4, 6, 1024)   0           batch_normalization_6[0][0]
#                                                                  batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 8, 12, 1024)  0           concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 8, 12, 512)   8389120     up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 8, 12, 512)   2048        conv2d_8[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 8, 12, 1024)  0           batch_normalization_7[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 16, 24, 1024) 0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 24, 512)  8389120     up_sampling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 16, 24, 512)  2048        conv2d_9[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 16, 24, 1024) 0           batch_normalization_8[0][0]
#                                                                  batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 32, 48, 1024) 0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 32, 48, 256)  4194560     up_sampling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 32, 48, 256)  1024        conv2d_10[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 32, 48, 512)  0           batch_normalization_9[0][0]
#                                                                  batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)  (None, 64, 96, 512)  0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 64, 96, 128)  1048704     up_sampling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 64, 96, 128)  512         conv2d_11[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 64, 96, 256)  0           batch_normalization_10[0][0]
#                                                                  batch_normalization[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_5 (UpSampling2D)  (None, 128, 192, 256 0           concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 128, 192, 64) 262208      up_sampling2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 128, 192, 64) 256         conv2d_12[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 128, 192, 128 0           batch_normalization_11[0][0]
#                                                                  leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_6 (UpSampling2D)  (None, 256, 384, 128 0           concatenate_5[0][0]
# __________________________________________________________________________________________________
# G_output (Conv2D)               (None, 256, 384, 3)  6147        up_sampling2d_6[0][0]
# ==================================================================================================
# Total params: 41,843,331
# Trainable params: 41,834,499
# Non-trainable params: 8,832
# __________________________________________________________________________________________________

# %%
def build_discriminator():

  df = 64
  def d_layer(layer_input, filters, f_size=4, bn=True):

      d = Conv2D(filters, kernel_size=f_size, strides=2, padding='same')(layer_input)
      d = LeakyReLU(alpha=0.2)(d)
      if bn:
          d = BatchNormalization(momentum=0.8)(d)
      return d

  image = Input(shape=img_shape, name="real_or_fake_A")
  condition = Input(shape=img_shape, name="condition")

  combined_imgs = Concatenate(axis=-1)([image, condition])

  d1 = d_layer(combined_imgs, df, bn=False)
  d2 = d_layer(d1, df*2)
  d3 = d_layer(d2, df*4)
  d4 = d_layer(d3, df*8)

  validity = Conv2D(1, kernel_size=4, strides=1, padding='same', name='D_output', activation='sigmoid')(d4)

  return Model([image, condition], validity, name='D')

# %%
dis = build_discriminator()
dis.summary()
# Out:
# Model: "D"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# real_or_fake_A (InputLayer)     [(None, 256, 384, 3) 0
# __________________________________________________________________________________________________
# condition (InputLayer)          [(None, 256, 384, 3) 0
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 256, 384, 6)  0           real_or_fake_A[0][0]
#                                                                  condition[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 128, 192, 64) 6208        concatenate_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 128, 192, 64) 0           conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 64, 96, 128)  131200      leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 64, 96, 128)  0           conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 64, 96, 128)  512         leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 32, 48, 256)  524544      batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)       (None, 32, 48, 256)  0           conv2d_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 32, 48, 256)  1024        leaky_re_lu_9[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 16, 24, 512)  2097664     batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)      (None, 16, 24, 512)  0           conv2d_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 16, 24, 512)  2048        leaky_re_lu_10[0][0]
# __________________________________________________________________________________________________
# D_output (Conv2D)               (None, 16, 24, 1)    8193        batch_normalization_14[0][0]
# ==================================================================================================
# Total params: 2,771,393
# Trainable params: 2,769,601
# Non-trainable params: 1,792
# __________________________________________________________________________________________________

# %%
def build_vgg():
  vgg_in = Input(img_shape)
  vgg = vgg19.VGG19(include_top=False, input_shape=img_shape, input_tensor=vgg_in)
  vgg_out = vgg.get_layer('block5_conv4').output
  vgg = Model(vgg_in, vgg_out, name='vgg')
  vgg.trainable = False

  return vgg

# %%
vgg = build_vgg()
vgg.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80142336/80134624 [==============================] - 2s 0us/step
# Model: "vgg"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 256, 384, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 256, 384, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 256, 384, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 128, 192, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 128, 192, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 128, 192, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 64, 96, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 64, 96, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 64, 96, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 64, 96, 256)       590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, 64, 96, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 32, 48, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 32, 48, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 32, 48, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 32, 48, 512)       2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, 32, 48, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 16, 24, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 16, 24, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 16, 24, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 16, 24, 512)       2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, 16, 24, 512)       2359808
# =================================================================
# Total params: 20,024,384
# Trainable params: 0
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %%
def build_gan(generator, discriminator, vgg):
  discriminator.trainable = False

  condition = Input(img_shape, name='Condition')
  fake_img = generator(condition)

  fake_features = vgg(fake_img)

  fake_validity = discriminator([fake_img, condition])

  gan = Model(condition, [fake_validity, fake_img, fake_features])

  return gan

# %%
dis.output_shape[1:]
# Out:
# (16, 24, 1)

# %%
(np.ones((128, *dis.output_shape[1:]))).shape
# Out:
# (128, 16, 24, 1)

# %%
def train(generator, discriminator, gan, vgg, imgs, masks, epochs, batch_size):

  for epoch in range(epochs):
    idx = np.random.choice(imgs.shape[0], imgs.shape[0], replace=False)

    with tqdm(total=imgs.shape[0]) as pbar:
      for batch in range(imgs.shape[0]//batch_size):

        y_real = np.ones((batch_size, *discriminator.output_shape[1:])) - np.random.random_sample((batch_size, *discriminator.output_shape[1:]))*0.2
        y_fake = np.random.random_sample((batch_size, *discriminator.output_shape[1:]))*0.2

        idx_batch = idx[batch*batch_size:(batch+1)*batch_size]

        real_imgs = (imgs[idx_batch]/127.5)-1
        condition = (masks[idx_batch]/127.5)-1

        fake_imgs = generator.predict(condition)
        d_loss_real = discriminator.train_on_batch([real_imgs, condition], y_real)
        d_loss_fake = discriminator.train_on_batch([fake_imgs, condition], y_fake)
        d_loss_total = 0.5*np.add(d_loss_real, d_loss_fake)

        real_features = vgg.predict(real_imgs)
        y_real = np.ones((batch_size, *discriminator.output_shape[1:]))

        g_loss = gan.train_on_batch(condition, [y_real, real_imgs, real_features])
        pbar.update(batch_size)
        pbar.set_description("Epoch: {}/{}, Discriminator loss: {}, Generator loss:{}".format(epoch+1, epochs, d_loss_total[0], g_loss))

# %%
gen = build_generator()

dis = build_discriminator()
dis.compile(loss='binary_crossentropy', optimizer=Adam(lr=1e-4, beta_1=0.5), metrics=['accuracy'])

vgg = build_vgg()

gan = build_gan(gen, dis, vgg)
gan.compile(loss=['binary_crossentropy', 'mse', 'mse'], loss_weights=[1,100,10], optimizer=Adam(lr=1e-4, beta_1=0.5))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80142336/80134624 [==============================] - 1s 0us/step

# %%
gen.summary()
# Out:
# Model: "G"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# condition (InputLayer)          [(None, 256, 384, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 128, 192, 64) 3136        condition[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 128, 192, 64) 0           conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 64, 96, 128)  131200      leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 64, 96, 128)  0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 64, 96, 128)  512         leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 48, 256)  524544      batch_normalization[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 32, 48, 256)  0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 32, 48, 256)  1024        leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 16, 24, 512)  2097664     batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 16, 24, 512)  0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 16, 24, 512)  2048        leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 8, 12, 512)   4194816     batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 8, 12, 512)   0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 8, 12, 512)   2048        leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 4, 6, 512)    4194816     batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 4, 6, 512)    0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 4, 6, 512)    2048        leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 2, 3, 512)    4194816     batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 2, 3, 512)    0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 2, 3, 512)    2048        leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 4, 6, 512)    0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 4, 6, 512)    4194816     up_sampling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 4, 6, 512)    2048        conv2d_7[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 4, 6, 1024)   0           batch_normalization_6[0][0]
#                                                                  batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 8, 12, 1024)  0           concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 8, 12, 512)   8389120     up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 8, 12, 512)   2048        conv2d_8[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 8, 12, 1024)  0           batch_normalization_7[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 16, 24, 1024) 0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 24, 512)  8389120     up_sampling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 16, 24, 512)  2048        conv2d_9[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 16, 24, 1024) 0           batch_normalization_8[0][0]
#                                                                  batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 32, 48, 1024) 0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 32, 48, 256)  4194560     up_sampling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 32, 48, 256)  1024        conv2d_10[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 32, 48, 512)  0           batch_normalization_9[0][0]
#                                                                  batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)  (None, 64, 96, 512)  0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 64, 96, 128)  1048704     up_sampling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 64, 96, 128)  512         conv2d_11[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 64, 96, 256)  0           batch_normalization_10[0][0]
#                                                                  batch_normalization[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_5 (UpSampling2D)  (None, 128, 192, 256 0           concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 128, 192, 64) 262208      up_sampling2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 128, 192, 64) 256         conv2d_12[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 128, 192, 128 0           batch_normalization_11[0][0]
#                                                                  leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_6 (UpSampling2D)  (None, 256, 384, 128 0           concatenate_5[0][0]
# __________________________________________________________________________________________________
# G_output (Conv2D)               (None, 256, 384, 3)  6147        up_sampling2d_6[0][0]
# ==================================================================================================
# Total params: 41,843,331
# Trainable params: 41,834,499
# Non-trainable params: 8,832
# __________________________________________________________________________________________________

# %%
dis.summary()
# Out:
# Model: "D"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# real_or_fake_A (InputLayer)     [(None, 256, 384, 3) 0
# __________________________________________________________________________________________________
# condition (InputLayer)          [(None, 256, 384, 3) 0
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 256, 384, 6)  0           real_or_fake_A[0][0]
#                                                                  condition[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 128, 192, 64) 6208        concatenate_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 128, 192, 64) 0           conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 64, 96, 128)  131200      leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 64, 96, 128)  0           conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 64, 96, 128)  512         leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 32, 48, 256)  524544      batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)       (None, 32, 48, 256)  0           conv2d_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 32, 48, 256)  1024        leaky_re_lu_9[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 16, 24, 512)  2097664     batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)      (None, 16, 24, 512)  0           conv2d_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 16, 24, 512)  2048        leaky_re_lu_10[0][0]
# __________________________________________________________________________________________________
# D_output (Conv2D)               (None, 16, 24, 1)    8193        batch_normalization_14[0][0]
# ==================================================================================================
# Total params: 2,771,393
# Trainable params: 0
# Non-trainable params: 2,771,393
# __________________________________________________________________________________________________

# %%
vgg.summary()
# Out:
# Model: "vgg"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 256, 384, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 256, 384, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 256, 384, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 128, 192, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 128, 192, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 128, 192, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 64, 96, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 64, 96, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 64, 96, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 64, 96, 256)       590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, 64, 96, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 32, 48, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 32, 48, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 32, 48, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 32, 48, 512)       2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, 32, 48, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 16, 24, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 16, 24, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 16, 24, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 16, 24, 512)       2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, 16, 24, 512)       2359808
# =================================================================
# Total params: 20,024,384
# Trainable params: 0
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %%
train(gen, dis, gan, vgg, imgs, masks, 15, 16)
# Out:
# Epoch: 1/15, Discriminator loss: 0.4724368155002594, Generator loss:[16.329090118408203, 1.9083690643310547, 0.13927702605724335, 0.04930190369486809]:  99%|█████████▉| 992/1000 [04:39<00:02,  3.55it/s]
# Epoch: 2/15, Discriminator loss: 0.4632374942302704, Generator loss:[20.12602996826172, 1.0476832389831543, 0.1859571486711502, 0.04826313257217407]:  99%|█████████▉| 992/1000 [04:39<00:02,  3.55it/s]
# Epoch: 3/15, Discriminator loss: 0.45523978769779205, Generator loss:[16.28521156311035, 1.2999522686004639, 0.1449814885854721, 0.04871106147766113]:  99%|█████████▉| 992/1000 [04:39<00:02,  3.55it/s]
# Epoch: 4/15, Discriminator loss: 0.8450587391853333, Generator loss:[16.856782913208008, 1.0032871961593628, 0.15374881029129028, 0.047861550003290176]:  99%|█████████▉| 992/1000 [04:39<00:02,  3.55it/s]
# Epoch: 5/15, Discriminator loss: 0.39083464443683624, Generator loss:[13.266755104064941, 1.2544223070144653, 0.11536122113466263, 0.047621045261621475]:  99%|█████████▉| 992/1000 [04:39<00:02,  3.55it/s]
# Epoch: 6/15, Discriminator loss: 0.5580082088708878, Generator loss:[13.92047119140625, 1.118605613708496, 0.12249483913183212, 0.05523820221424103]:  99%|█████████▉| 992/1000 [04:39<00:02,  3.55it/s]
# Epoch: 7/15, Discriminator loss: 0.6936972439289093, Generator loss:[11.971847534179688, 1.4755138158798218, 0.09966829419136047, 0.05295052006840706]:  99%|█████████▉| 992/1000 [04:39<00:02,  3.55it/s]
# Epoch: 8/15, Discriminator loss: 0.40894198417663574, Generator loss:[14.105134963989258, 1.9695295095443726, 0.1161879301071167, 0.051681261509656906]:  99%|█████████▉| 992/1000 [04:39<00:02,  3.55it/s]
# Epoch: 9/15, Discriminator loss: 0.4170546233654022, Generator loss:[9.796099662780762, 1.7269887924194336, 0.07568502426147461, 0.050060808658599854]:  99%|█████████▉| 992/1000 [04:39<00:02,  3.55it/s]
# Epoch: 10/15, Discriminator loss: 0.3913453221321106, Generator loss:[11.366941452026367, 2.107494592666626, 0.08781460672616959, 0.04779863730072975]:  99%|█████████▉| 992/1000 [04:39<00:02,  3.55it/s]
# Epoch: 11/15, Discriminator loss: 0.43933121860027313, Generator loss:[10.50852108001709, 2.341571092605591, 0.07662281394004822, 0.050466831773519516]:  99%|█████████▉| 992/1000 [04:39<00:02,  3.55it/s]
# Epoch: 12/15, Discriminator loss: 0.4523143321275711, Generator loss:[9.458282470703125, 1.7721256017684937, 0.07208427786827087, 0.047772929072380066]:  99%|█████████▉| 992/1000 [04:39<00:02,  3.55it/s]
# Epoch: 13/15, Discriminator loss: 0.3843517452478409, Generator loss:[11.24583625793457, 2.255481243133545, 0.08546986430883408, 0.04433690384030342]:  99%|█████████▉| 992/1000 [04:39<00:02,  3.55it/s]
# Epoch: 14/15, Discriminator loss: 0.7617972791194916, Generator loss:[9.324687957763672, 2.2230265140533447, 0.06635484099388123, 0.046617671847343445]:  99%|█████████▉| 992/1000 [04:39<00:02,  3.55it/s]
# Epoch: 15/15, Discriminator loss: 0.5203862190246582, Generator loss:[7.882080554962158, 1.3909636735916138, 0.06073611602187157, 0.04175051674246788]:  99%|█████████▉| 992/1000 [04:39<00:02,  3.55it/s]

# %%
def sample_image(generator, imgs, masks, idx):
    fig, ax = plt.subplots(1,3, figsize=(15,5))


    ax[0].imshow(masks[idx])
    ax[0].set_title('маска')

    condition = masks[idx]/127.5-1
    generated = (generator.predict(condition[None])+1)*127.5

    ax[1].imshow(generated[0].astype('uint8'))
    ax[1].set_title('сгенерированное изображение')

    ax[2].imshow(imgs[idx])
    ax[2].set_title('реальное изображение')

# %%
for i in [20,100,300,500]:
   sample_image(gen, imgs, masks, i)
